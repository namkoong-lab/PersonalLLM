# %%
import pandas as pd

df = pd.read_csv('/user/as6154/personalize/personalize/eval/scores/all_scores.csv')
df
# Out:
#       eval_type               generator  debug  total_score  \
# 0        reward        OneShotGenerator  False -1092.517469
# 1        reward     VanillaICLGenerator  False -1037.265498
# 2   binary_pref     VanillaICLGenerator  False -1485.575803
# 3        reward     VanillaICLGenerator  False    -1.092469
# 4   binary_pref     VanillaICLGenerator  False    -2.759763
# 5        reward     OneShotICLGenerator  False    -1.202550
# 6   binary_pref     OneShotICLGenerator  False    -2.129251
# 7        reward   ThreeShotICLGenerator  False    -1.097026
# 8   binary_pref   ThreeShotICLGenerator  False    -2.735820
# 9   binary_pref     VanillaICLGenerator  False    -2.759763
# 10       reward      MetaLearnGenerator   True    -1.355899
# 11       reward      MetaLearnGenerator   True    -1.355899
# 12       reward      MetaLearnGenerator  False    -1.410556
# 13       reward  MetaLearnTenKGenerator   True    -1.238129
# 14       reward     OneShotICLGenerator  False    -1.202550
# ...
